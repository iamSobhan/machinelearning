# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv("creditcard.csv")

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card_data.shape
# Out:
# (284807, 31)

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#This Dataset is very Unbalanced. So separating data for further analysis.

#0 --- Normal Transaction
#1 --- Fraud Transaction

# %%
normal = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(normal.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both transaction

credit_card_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Under-Sampling
#Build a sample dataset containing similar distribution of normal transactions and fraud transactions.

# %%
normal_sample = normal.sample(n = 492)

# %%
#Concatenation of two DataFrames

new_credit_card_data = pd.concat([normal_sample, fraud], axis = 0) #axis = 0 means the dataset added one by one, all the 492 values wiil be added below the normal_sample.

# %%
new_credit_card_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 31526    36398.0  0.700918 -2.068451  0.514509 -0.202706 -1.462429  0.922577
# 71710    54416.0 -0.459345 -0.164999  2.521979  0.342960 -0.583564  1.375512
# 241397  151009.0 -0.260854  0.049315  1.709005 -0.762225 -0.077438  0.472883
# 105959   69762.0 -1.694846 -0.070450  2.498739 -0.753366 -0.863360 -1.012253
# 244461  152363.0  0.072480  0.901467 -0.345040 -0.611263  0.856270 -0.623219
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 31526  -0.917818  0.212001  0.438227  ...  0.361093  0.626203 -0.518362
# 71710  -0.187984  0.480556  1.256914  ... -0.076314  0.252804 -0.030281
# 241397 -0.091778  0.114072  0.952890  ...  0.416559  1.447428  0.072094
# 105959 -0.551375  0.597930  0.038814  ...  0.392733  0.611578 -0.132730
# 244461  0.808004  0.073966 -0.196154  ... -0.287370 -0.764153  0.116986
#
# ...

# %%
new_credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_credit_card_data.shape
# Out:
# (984, 31)

# %%
new_credit_card_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     984.000000  984.000000  984.000000  984.000000  984.000000
# mean    88102.433943   -2.411700    1.873143   -3.518229    2.202471
# std     47759.682658    5.494088    3.649416    6.222884    3.268343
# min       284.000000  -30.552380  -10.743893  -31.103685   -4.678263
# 25%     46221.750000   -2.877893   -0.122196   -5.138122   -0.271986
# 50%     81349.500000   -0.805152    1.001542   -1.361701    1.305164
# 75%    134158.250000    0.917444    2.814266    0.325456    4.250632
# max    171983.000000    2.360449   22.057729    3.203999   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  ...
# mean    -1.523072   -0.664004   -2.798437    0.271245   -1.287499  ...
# std      4.241326    1.810392    5.852132    4.907613    2.323658  ...
# ...

# %%
new_credit_card_data["Class"].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
new_credit_card_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95458.060976 -0.051451  0.122507 -0.003178 -0.137087  0.105080
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.069729 -0.028144 -0.028145  0.006125  ...  0.037233  0.041629
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.053018 -0.012691  0.042754  0.007899  0.000881  0.012007 -0.005585
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       73.022175
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_credit_card_data.drop(columns = "Class", axis = 1)
Y = new_credit_card_data["Class"]

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 31526    36398.0  0.700918 -2.068451  0.514509 -0.202706 -1.462429  0.922577
# 71710    54416.0 -0.459345 -0.164999  2.521979  0.342960 -0.583564  1.375512
# 241397  151009.0 -0.260854  0.049315  1.709005 -0.762225 -0.077438  0.472883
# 105959   69762.0 -1.694846 -0.070450  2.498739 -0.753366 -0.863360 -1.012253
# 244461  152363.0  0.072480  0.901467 -0.345040 -0.611263  0.856270 -0.623219
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 31526     0
# 71710     0
# 241397    0
# 105959    0
# 244461    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 1)

# %%
print(X.shape)
# Out:
# (984, 30)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (787, 30) (197, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on Training Data: ", training_data_accuracy)
# Out:
# Accuracy on Training Data:  0.9123252858958069

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy on Test Data: ", test_data_accuracy)
# Out:
# Accuracy on Test Data:  0.9035532994923858

# %%
credit_card_details = (2,-0.425965884412454,0.960523044882985,1.14110934232219,-0.168252079760302,0.42098688077219,-0.0297275516639742,0.476200948720027,0.260314333074874,-0.56867137571251,-0.371407196834471,1.34126198001957,0.359893837038039,-0.358090652573631,-0.137133700217612,0.517616806555742,0.401725895589603,-0.0581328233640131,0.0686531494425432,-0.0331937877876282,0.0849676720682049,-0.208253514656728,-0.559824796253248,-0.0263976679795373,-0.371426583174346,-0.232793816737034,0.105914779097957,0.253844224739337,0.0810802569229443,3.67)
credit_card_values_as_numpy_array = np.asarray(credit_card_details)
credit_card_details_reshaped = credit_card_values_as_numpy_array.reshape(1,-1)

prediction = model.predict(credit_card_details_reshaped)
print(prediction)

if(prediction[0] == 0):
    print("This Transaction is Normal.")
else:
    print("This Transaction is Fraud.")
# Out:
# [0]
# This Transaction is Normal.
