# %%
import pandas as pd

# %%
amazon_order = pd.read_csv("sayandip_amazon_order_history.csv")

# %%
amazon_order.head()
# Out:
#               order id                                              items  \
# 0  405-0003762-5437921  NESCAFÉ The Ultimate Coffee Kit - Nescafe Clas...
# 1  408-7891735-2418709            Amazon Pay balance: Money (Cash-load);
# 2  405-9078959-7873142  Dr Trust USA Gold Standard Blood Glucose Test ...
# 3  405-9733244-4955544  Jik Store Back-Flow Monk Ganesh Incense Burner...
# 4  405-5267364-3897943  BETALA FRAGRANCE backflow incense dhoop cones,...
#
#               to        date      total   shipping shipping_refund gift VAT  \
# 0  SAYANDIP JANA  2021-12-17  Rs.665.00  Rs. 40.00               0    0   0
# 1              0  2021-12-05          0          0               0    0   0
# 2  SAYANDIP JANA  2021-11-30  Rs.749.00  Rs. 40.00               0    0   0
# 3  SAYANDIP JANA  2021-11-11  Rs.168.00  Rs. 45.00               0    0   0
# 4  SAYANDIP JANA  2021-11-11  Rs.260.00   Rs. 0.00               0    0   0
#
#   refund   payments
# 0      0  UNKNOWN;
# 1      0  UNKNOWN;
# ...

# %%
amazon_order.shape
# Out:
# (41, 11)

# %%
amazon_order.columns
# Out:
# Index(['order id', 'items', 'to', 'date', 'total', 'shipping',
#        'shipping_refund', 'gift', 'VAT', 'refund', 'payments'],
#       dtype='object')

# %%
amazon_order.columns = ['OrderId', 'PurchasedItems', 'CoustomerName', 'OrderDate', 'AmountPaid', 'ShippingCharges', 'RefundOnShippingCharges', 'Gift', 'Vat', 'TotalRefund', 'PaymentsMethod']

# %%
amazon_order.columns
# Out:
# Index(['OrderId', 'PurchasedItems', 'CoustomerName', 'OrderDate', 'AmountPaid',
#        'ShippingCharges', 'RefundOnShippingCharges', 'Gift', 'Vat',
#        'TotalRefund', 'PaymentsMethod'],
#       dtype='object')

# %%
amazon_order.drop("Gift", axis = 1)
# Out:
#                 OrderId                                     PurchasedItems  \
# 0   405-0003762-5437921  NESCAFÉ The Ultimate Coffee Kit - Nescafe Clas...
# 1   408-7891735-2418709            Amazon Pay balance: Money (Cash-load);
# 2   405-9078959-7873142  Dr Trust USA Gold Standard Blood Glucose Test ...
# 3   405-9733244-4955544  Jik Store Back-Flow Monk Ganesh Incense Burner...
# 4   405-5267364-3897943  BETALA FRAGRANCE backflow incense dhoop cones,...
# 5   405-6165870-5850763  Steelbird Helmet Visor Compatible for All SBA-...
# 6   405-0677865-3480309  Noise Flair in-Ear Wireless Bluetooth Smart Ne...
# 7   408-7762891-3816341            Amazon Pay balance: Money (Cash-load);
# 8   405-9623015-8633136  BVB mart 46 in 1 Pcs Tool Kit & Screwdriver an...
# 9   408-6188597-7267506  Gadget Deals 5W - USB Light Emergencey use USB...
# 10  405-3319950-0533926          Mobile Prepaid Recharge; Recharge Again;
# ...

# %%
amazon_order[0 : 40]
# Out:
#                 OrderId                                     PurchasedItems  \
# 0   405-0003762-5437921  NESCAFÉ The Ultimate Coffee Kit - Nescafe Clas...
# 1   408-7891735-2418709            Amazon Pay balance: Money (Cash-load);
# 2   405-9078959-7873142  Dr Trust USA Gold Standard Blood Glucose Test ...
# 3   405-9733244-4955544  Jik Store Back-Flow Monk Ganesh Incense Burner...
# 4   405-5267364-3897943  BETALA FRAGRANCE backflow incense dhoop cones,...
# 5   405-6165870-5850763  Steelbird Helmet Visor Compatible for All SBA-...
# 6   405-0677865-3480309  Noise Flair in-Ear Wireless Bluetooth Smart Ne...
# 7   408-7762891-3816341            Amazon Pay balance: Money (Cash-load);
# 8   405-9623015-8633136  BVB mart 46 in 1 Pcs Tool Kit & Screwdriver an...
# 9   408-6188597-7267506  Gadget Deals 5W - USB Light Emergencey use USB...
# 10  405-3319950-0533926          Mobile Prepaid Recharge; Recharge Again;
# ...

# %%
amazon_order_details = amazon_order[0 : 40]

# %%
amazon_order_details.head()
# Out:
#                OrderId                                     PurchasedItems  \
# 0  405-0003762-5437921  NESCAFÉ The Ultimate Coffee Kit - Nescafe Clas...
# 1  408-7891735-2418709            Amazon Pay balance: Money (Cash-load);
# 2  405-9078959-7873142  Dr Trust USA Gold Standard Blood Glucose Test ...
# 3  405-9733244-4955544  Jik Store Back-Flow Monk Ganesh Incense Burner...
# 4  405-5267364-3897943  BETALA FRAGRANCE backflow incense dhoop cones,...
#
#    CoustomerName   OrderDate AmountPaid ShippingCharges  \
# 0  SAYANDIP JANA  2021-12-17  Rs.665.00       Rs. 40.00
# 1              0  2021-12-05          0               0
# 2  SAYANDIP JANA  2021-11-30  Rs.749.00       Rs. 40.00
# 3  SAYANDIP JANA  2021-11-11  Rs.168.00       Rs. 45.00
# 4  SAYANDIP JANA  2021-11-11  Rs.260.00        Rs. 0.00
#
#   RefundOnShippingCharges Gift Vat TotalRefund PaymentsMethod
# 0                       0    0   0           0      UNKNOWN;
# ...

# %%
amazon_order_details["AmountPaid"] = amazon_order_details["AmountPaid"].str.replace("Rs.", "").str.replace(",", "")
# Out:
# <ipython-input-15-d240c867360a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_order_details["AmountPaid"] = amazon_order_details["AmountPaid"].str.replace("Rs.", "").str.replace(",", "")

# %%
amazon_order_details["AmountPaid"].astype(float)
# Out:
# 0      665.0
# 1        0.0
# 2      749.0
# 3      168.0
# 4      260.0
# 5      719.0
# 6     1799.0
# 7        0.0
# 8      999.0
# 9        0.0
# 10       0.0
# 11     658.0
# 12     199.0
# 13     613.0
# 14       0.0
# 15       0.0
# 16       0.0
# 17       0.0
# 18       0.0
# 19       0.0
# 20       0.0
# 21       0.0
# 22       0.0
# 23    1999.0
# 24       0.0
# 25    1199.0
# 26     730.0
# 27     389.0
# 28    1790.0
# 29    3999.0
# 30       0.0
# 31     269.0
# 32    1300.0
# 33    1199.0
# 34     999.0
# 35     680.0
# 36     239.0
# 37       0.0
# 38       0.0
# 39       0.0
# Name: AmountPaid, dtype: float64

# %%
amazon_order_details["AmountPaid"].sum()
# Out:
# '665.000749.00168.00260.00719.001799.000999.000.000658.00199.00613.000000000001999.0001199.00730.00389.001790.003999.000269.001300.001199.00999.00680.00239.00000.00'

# %%
amazon_order_details["AmountPaid"] = amazon_order_details["AmountPaid"].astype(float)
# Out:
# <ipython-input-21-a6e3fa1af6c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_order_details["AmountPaid"] = amazon_order_details["AmountPaid"].astype(float)

# %%
amazon_order_details["AmountPaid"].sum()
# Out:
# 21621.0

# %%
amazon_order_details["AmountPaid"].mean()
# Out:
# 540.525

# %%
amazon_order_details["AmountPaid"].median()
# Out:
# 219.0

# %%
amazon_order_details["AmountPaid"].max()
# Out:
# 3999.0
